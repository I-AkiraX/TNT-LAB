# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('income.xlsx')

# %%
df.head()
# Out:
#     age      JobType        EdType       maritalstatus      occupation  \
# 0  45.0      Private       HS-grad            Divorced    Adm-clerical
# 1  24.0  Federal-gov       HS-grad       Never-married    Armed-Forces
# 2  44.0      Private  Some-college  Married-civ-spouse  Prof-specialty
# 3  27.0      Private           9th       Never-married    Craft-repair
# 4  20.0      Private  Some-college       Never-married           Sales
#
#      relationship   race  gender  capitalgain  capitalloss  hoursperweek  \
# 0   Not-in-family  White  Female          0.0          0.0          28.0
# 1       Own-child  White    Male          0.0          0.0          40.0
# 2         Husband  White    Male          0.0          0.0          40.0
# 3  Other-relative  White    Male          0.0          0.0          40.0
# 4   Not-in-family  White    Male          0.0          0.0          35.0
#
#    nativecountry                        SalStat
# 0  United-States   less than or equal to 50,000
# 1  United-States   less than or equal to 50,000
# 2  United-States            greater than 50,000
# 3         Mexico   less than or equal to 50,000
# 4  United-States   less than or equal to 50,000

# %%
df.drop(columns=['capitalgain', 'capitalloss'], inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'JobType', 'EdType', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'gender', 'hoursperweek', 'nativecountry',
#        'SalStat'],
#       dtype='object')

# %%
cols = ['JobType', 'EdType', 'maritalstatus', 'occupation', 'relationship', 'race', 
        'gender', 'nativecountry', 'SalStat']

for col in cols:
    le = preprocessing.LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#     age  JobType  EdType  maritalstatus  occupation  relationship  race  \
# 0  45.0        4      11              0           1             1     4
# 1  24.0        1      11              4           2             3     4
# 2  44.0        4      15              2          10             0     4
# 3  27.0        4       6              4           3             2     4
# 4  20.0        4      15              4          12             1     4
#
#    gender  hoursperweek  nativecountry  SalStat
# 0       0          28.0             38        1
# 1       1          40.0             38        1
# 2       1          40.0             38        0
# 3       1          40.0             25        1
# 4       1          35.0             38        1

# %%
df.SalStat.value_counts()
# Out:
# 1    24283
# 0     7695
# Name: SalStat, dtype: int64

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ebeea_row0_col0, #T_ebeea_row1_col1, #T_ebeea_row2_col2, #T_ebeea_row3_col3, #T_ebeea_row4_col4, #T_ebeea_row5_col5, #T_ebeea_row6_col6, #T_ebeea_row7_col7, #T_ebeea_row8_col8, #T_ebeea_row9_col9, #T_ebeea_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ebeea_row0_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ebeea_row0_col2, #T_ebeea_row5_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ebeea_row0_col3, #T_ebeea_row0_col10, #T_ebeea_row3_col0, #T_ebeea_row3_col9, #T_ebeea_row5_col0, #T_ebeea_row5_col1, #T_ebeea_row5_col4, #T_ebeea_row5_col6, #T_ebeea_row5_col7, #T_ebeea_row5_col8, #T_ebeea_row7_col5, #T_ebeea_row8_col10, #T_ebeea_row10_col2, #T_ebeea_row10_col4, #T_ebeea_row10_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ebeea_row0_col4, #T_ebeea_row2_col4, #T_ebeea_row4_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ebeea_row0_col5, #T_ebeea_row2_col0, #T_ebeea_row4_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ebeea_row0_col6, #T_ebeea_row6_col1, #T_ebeea_row6_col10 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ebeea_row0_col7, #T_ebeea_row6_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_ebeea_row0_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ebeea_row0_col9, #T_ebeea_row3_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ebeea_row1_col0, #T_ebeea_row9_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ebeea_row1_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ebeea_row1_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ebeea_row1_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_ebeea_row1_col5, #T_ebeea_row1_col8 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ebeea_row1_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ebeea_row1_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ebeea_row1_col9, #T_ebeea_row4_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ebeea_row1_col10, #T_ebeea_row7_col4, #T_ebeea_row8_col4, #T_ebeea_row8_col6, #T_ebeea_row9_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ebeea_row2_col1, #T_ebeea_row7_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ebeea_row2_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_ebeea_row2_col5, #T_ebeea_row9_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_ebeea_row2_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ebeea_row2_col7, #T_ebeea_row3_col10 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ebeea_row2_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ebeea_row2_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_ebeea_row2_col10 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ebeea_row3_col2, #T_ebeea_row10_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ebeea_row3_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ebeea_row3_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_ebeea_row3_col6, #T_ebeea_row3_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ebeea_row3_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ebeea_row4_col0, #T_ebeea_row9_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ebeea_row4_col1, #T_ebeea_row4_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ebeea_row4_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ebeea_row4_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_ebeea_row4_col8, #T_ebeea_row8_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_ebeea_row4_col10, #T_ebeea_row8_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ebeea_row5_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ebeea_row5_col9, #T_ebeea_row7_col10, #T_ebeea_row10_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ebeea_row5_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_ebeea_row6_col0, #T_ebeea_row10_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_ebeea_row6_col2 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ebeea_row6_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_ebeea_row6_col4, #T_ebeea_row9_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ebeea_row6_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_ebeea_row6_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ebeea_row6_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ebeea_row7_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ebeea_row7_col1, #T_ebeea_row9_col10 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_ebeea_row7_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ebeea_row7_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_ebeea_row7_col8 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ebeea_row7_col9, #T_ebeea_row10_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ebeea_row8_col1, #T_ebeea_row8_col5, #T_ebeea_row9_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ebeea_row8_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ebeea_row8_col7 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_ebeea_row8_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ebeea_row9_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ebeea_row9_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ebeea_row9_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ebeea_row10_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ebeea_row10_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_ebeea_row10_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ebeea_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >JobType</th>
#       <th class="col_heading level0 col2" >EdType</th>
#       <th class="col_heading level0 col3" >maritalstatus</th>
#       <th class="col_heading level0 col4" >occupation</th>
#       <th class="col_heading level0 col5" >relationship</th>
#       <th class="col_heading level0 col6" >race</th>
#       <th class="col_heading level0 col7" >gender</th>
#       <th class="col_heading level0 col8" >hoursperweek</th>
#       <th class="col_heading level0 col9" >nativecountry</th>
#       <th class="col_heading level0 col10" >SalStat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebeea_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_ebeea_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ebeea_row0_col1" class="data row0 col1" >0.002941</td>
#       <td id="T_ebeea_row0_col2" class="data row0 col2" >-0.009375</td>
#       <td id="T_ebeea_row0_col3" class="data row0 col3" >-0.265736</td>
#       <td id="T_ebeea_row0_col4" class="data row0 col4" >-0.020929</td>
#       <td id="T_ebeea_row0_col5" class="data row0 col5" >-0.264718</td>
#       <td id="T_ebeea_row0_col6" class="data row0 col6" >0.026615</td>
#       <td id="T_ebeea_row0_col7" class="data row0 col7" >0.089035</td>
#       <td id="T_ebeea_row0_col8" class="data row0 col8" >0.068299</td>
#       <td id="T_ebeea_row0_col9" class="data row0 col9" >-0.000323</td>
#       <td id="T_ebeea_row0_col10" class="data row0 col10" >-0.233601</td>
#     </tr>
#     <tr>
#       <th id="T_ebeea_level0_row1" class="row_heading level0 row1" >JobType</th>
#       <td id="T_ebeea_row1_col0" class="data row1 col0" >0.002941</td>
#       <td id="T_ebeea_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ebeea_row1_col2" class="data row1 col2" >0.024515</td>
#       <td id="T_ebeea_row1_col3" class="data row1 col3" >-0.065426</td>
#       <td id="T_ebeea_row1_col4" class="data row1 col4" >0.255280</td>
#       <td id="T_ebeea_row1_col5" class="data row1 col5" >-0.090504</td>
#       <td id="T_ebeea_row1_col6" class="data row1 col6" >0.051732</td>
#       <td id="T_ebeea_row1_col7" class="data row1 col7" >0.094961</td>
#       <td id="T_ebeea_row1_col8

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(columns = ['SalStat']), df['SalStat'], test_size = 0.2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((25582, 10), (25582,), (6396, 10), (6396,))

# %%
algos = []
accuracy = []
recall = []
precision = []
f1Score = []

# %%
algo = "Logistic Regression"
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(algo)
print(confusion_matrix(y_test, y_pred), '\n\n')
acc = accuracy_score(y_test, y_pred) * 100
print('Accuracy:', acc)
rec = recall_score(y_test, y_pred) * 100
print('Recall:', rec)
pre = precision_score(y_test, y_pred) * 100
print('Precision:', pre)
f1s = f1_score(y_test, y_pred) * 100
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
# Out:
# Logistic Regression
# [[ 226 1338]
#  [ 258 4574]]
#
#
# Accuracy: 75.046904315197
# Recall: 94.66059602649007
# Precision: 77.3680649526387
# F score: 85.1451973194341

# %%
algo = "K Nearest Neighbour"
model = KNeighborsClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(algo)
print(confusion_matrix(y_test, y_pred), '\n\n')
acc = accuracy_score(y_test, y_pred) * 100
print('Accuracy:', acc)
rec = recall_score(y_test, y_pred) * 100
print('Recall:', rec)
pre = precision_score(y_test, y_pred) * 100
print('Precision:', pre)
f1s = f1_score(y_test, y_pred) * 100
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
# Out:
# K Nearest Neighbour
# [[ 816  748]
#  [ 608 4224]]
#
#
# Accuracy: 78.79924953095684
# Recall: 87.41721854304636
# Precision: 84.95575221238938
# F score: 86.16891064871481

# %%
algo = "Decision Tree"
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(algo)
print(confusion_matrix(y_test, y_pred), '\n\n')
acc = accuracy_score(y_test, y_pred) * 100
print('Accuracy:', acc)
rec = recall_score(y_test, y_pred) * 100
print('Recall:', rec)
pre = precision_score(y_test, y_pred) * 100
print('Precision:', pre)
f1s = f1_score(y_test, y_pred) * 100
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
# Out:
# Decision Tree
# [[ 884  680]
#  [ 707 4125]]
#
#
# Accuracy: 78.31457160725454
# Recall: 85.36837748344371
# Precision: 85.8480749219563
# F score: 85.60755421811767

# %%
algo = "Naive Bayes"
model = GaussianNB()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(algo)
print(confusion_matrix(y_test, y_pred), '\n\n')
acc = accuracy_score(y_test, y_pred) * 100
print('Accuracy:', acc)
rec = recall_score(y_test, y_pred) * 100
print('Recall:', rec)
pre = precision_score(y_test, y_pred) * 100
print('Precision:', pre)
f1s = f1_score(y_test, y_pred) * 100
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
# Out:
# Naive Bayes
# [[1054  510]
#  [1030 3802]]
#
#
# Accuracy: 75.92245153220762
# Recall: 78.68377483443709
# Precision: 88.17254174397031
# F score: 83.15835520559929

# %%
algo = "Random Forest"
model = RandomForestClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(algo)
print(confusion_matrix(y_test, y_pred), '\n\n')
acc = accuracy_score(y_test, y_pred) * 100
print('Accuracy:', acc)
rec = recall_score(y_test, y_pred) * 100
print('Recall:', rec)
pre = precision_score(y_test, y_pred) * 100
print('Precision:', pre)
f1s = f1_score(y_test, y_pred) * 100
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
# Out:
# Random Forest
# [[ 853  711]
#  [ 446 4386]]
#
#
# Accuracy: 81.91056910569105
# Recall: 90.76986754966887
# Precision: 86.05061801059448
# F score: 88.34726558565816

# %%
for i in range(5):
    print(algos[i], ':     ', accuracy[i],',  ', recall[i],',  ', precision[i],',  ', f1Score[i])
# Out:
# Logistic Regression :      75.046904315197 ,   94.66059602649007 ,   77.3680649526387 ,   85.1451973194341
# K Nearest Neighbour :      78.79924953095684 ,   87.41721854304636 ,   84.95575221238938 ,   86.16891064871481
# Decision Tree :      78.31457160725454 ,   85.36837748344371 ,   85.8480749219563 ,   85.60755421811767
# Naive Bayes :      75.92245153220762 ,   78.68377483443709 ,   88.17254174397031 ,   83.15835520559929
# Random Forest :      81.91056910569105 ,   90.76986754966887 ,   86.05061801059448 ,   88.34726558565816

# %%
plt.bar(algos, accuracy)
plt.show()
